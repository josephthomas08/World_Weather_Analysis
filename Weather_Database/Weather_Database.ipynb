# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lats_lngs)

# %%
# Get the nearest city.
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]). city_name
# If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
print(city)
# Out:
# lorengau

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4b481dfaa86ffa838b123c2cb999390d

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        weather_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vaini
# Processing Record 2 of Set 1 | butaritari
# Processing Record 3 of Set 1 | klaeng
# Processing Record 4 of Set 1 | narsaq
# Processing Record 5 of Set 1 | aklavik
# Processing Record 6 of Set 1 | ada
# Processing Record 7 of Set 1 | crestline
# Processing Record 8 of Set 1 | bogo
# Processing Record 9 of Set 1 | nikolayevsk-na-amure
# Processing Record 10 of Set 1 | chuy
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | hithadhoo
# Processing Record 13 of Set 1 | barrow
# Processing Record 14 of Set 1 | samarai
# Processing Record 15 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 1 | clyde river
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | souillac
# Processing Record 19 of Set 1 | norman wells
# Processing Record 20 of Set 1 | fairbanks
# Processing Record 21 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 1 | buk
# Processing Record 23 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | kamaishi
# Processing Record 26 of Set 1 | casablanca
# Processing Record 27 of Set 1 | tateyama
# Processing Record 28 of Set 1 | kilindoni
# Processing Record 29 of Set 1 | georgetown
# Processing Record 30 of Set 1 | asau
# Processing Record 31 of Set 1 | catuday
# Processing Record 32 of Set 1 | port elizabeth
# Processing Record 33 of Set 1 | yellowknife
# Processing Record 34 of Set 1 | shibetsu
# Processing Record 35 of Set 1 | zelenets
# Processing Record 36 of Set 1 | victoria
# Processing Record 37 of Set 1 | sao filipe
# Processing Record 38 of Set 1 | arraial do cabo
# Processing Record 39 of Set 1 | marzuq
# Processing Record 40 of Set 1 | dikson
# Processing Record 41 of Set 1 | tasiilaq
# Processing Record 42 of Set 1 | freeport
# Processing Record 43 of Set 1 | bethel
# Processing Record 44 of Set 1 | broome
# Processing Record 45 of Set 1 | la rioja
# Processing Record 46 of Set 1 | benguela
# Processing Record 47 of Set 1 | albany
# Processing Record 48 of Set 1 | teya
# Processing Record 49 of Set 1 | banjar
# Processing Record 50 of Set 1 | barcelos
# Processing Record 1 of Set 2 | busselton
# Processing Record 2 of Set 2 | qaqortoq
# Processing Record 3 of Set 2 | kismayo
# Processing Record 4 of Set 2 | hilo
# Processing Record 5 of Set 2 | jamestown
# Processing Record 6 of Set 2 | kirkwall
# Processing Record 7 of Set 2 | rawson
# Processing Record 8 of Set 2 | edgewood
# Processing Record 9 of Set 2 | fortuna
# Processing Record 10 of Set 2 | verbilki
# Processing Record 11 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 2 | mar del plata
# Processing Record 13 of Set 2 | oeiras
# Processing Record 14 of Set 2 | hualmay
# Processing Record 15 of Set 2 | carnarvon
# Processing Record 16 of Set 2 | punta arenas
# Processing Record 17 of Set 2 | isangel
# Processing Record 18 of Set 2 | bambous virieux
# Processing Record 19 of Set 2 | bandarbeyla
# Processing Record 20 of Set 2 | hermanus
# Processing Record 21 of Set 2 | upernavik
# Processing Record 22 of Set 2 | ixtapa
# Processing Record 23 of Set 2 | luderitz
# Processing Record 24 of Set 2 | kapaa
# Processing Record 25 of Set 2 | zaysan
# Processing Record 26 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 2 | pevek
# Processing Record 28 of Set 2 | bluff
# Processing Record 29 of Set 2 | torbay
# Processing Record 30 of Set 2 | saskylakh
# Processing Record 31 of Set 2 | ponta do sol
# Processing Record 32 of Set 2 | castro
# Processing Record 33 of Set 2 | skibbereen
# Processing Record 34 of Set 2 | telde
# Processing Record 35 of Set 2 | namibe
# Processing Record 36 of Set 2 | nanortalik
# Processing Record 37 of Set 2 | saint-philippe
# Processing Record 38 of Set 2 | civita castellana
# Processing Record 39 of Set 2 | qrendi
# Processing Record 40 of Set 2 | kitui
# Processing Record 41 of Set 2 | boa vista
# Processing Record 42 of Set 2 | cape town
# Processing Record 43 of Set 2 | faya
# Processing Record 44 of Set 2 | stokmarknes
# Processing Record 45 of Set 2 | shido
# Processing Record 46 of Set 2 | kamina
# Processing Record 47 of Set 2 | sarangani
# Processing Record 48 of Set 2 | avarua
# Processing Record 49 of Set 2 | zaraza
# Processing Record 50 of Set 2 | luanda
# Processing Record 1 of Set 3 | vanimo
# Processing Record 2 of Set 3 | bengkulu
# Processing Record 3 of Set 3 | orodara
# Processing Record 4 of Set 3 | vestmannaeyjar
# Processing Record 5 of Set 3 | ribeira grande
# Processing Record 6 of Set 3 | meulaboh
# Processing Record 7 of Set 3 | puerto ayora
# Processing Record 8 of Set 3 | tiksi
# Processing Record 9 of Set 3 | dingle
# Processing Record 10 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 3 | bagdarin
# Processing Record 12 of Set 3 | qaanaaq
# Processing Record 13 of Set 3 | margate
# Processing Record 14 of Set 3 | gornopravdinsk
# Processing Record 15 of Set 3 | provideniya
# Processing Record 16 of Set 3 | ostrovnoy
# Processing Record 17 of Set 3 | eureka
# Processing Record 18 of Set 3 | gavle
# Processing Record 19 of Set 3 | murray bridge
# Processing Record 20 of Set 3 | anzhero-sudzhensk
# Processing Record 21 of Set 3 | bambanglipuro
# Processing Record 22 of Set 3 | san carlos de bariloche
# Processing Record 23 of Set 3 | namatanai
# Processing Record 24 of Set 3 | tuktoyaktuk
# Processing Record 25 of Set 3 | castlemaine
# Processing Record 26 of Set 3 | saint austell
# Processing Record 27 of Set 3 | terrace
# Processing Record 28 of Set 3 | koungou
# Processing Record 29 of Set 3 | borama
# City not found. Skipping...
# Processing Record 30 of Set 3 | marawi
# Processing Record 31 of Set 3 | port alfred
# Processing Record 32 of Set 3 | pisco
# Processing Record 33 of Set 3 | rojhan
# Processing Record 34 of Set 3 | saint-augustin
# Processing Record 35 of Set 3 | khatanga
# Processing Record 36 of Set 3 | saurimo
# Processing Record 37 of Set 3 | montrose
# Processing Record 38 of Set 3 | skjervoy
# Processing Record 39 of Set 3 | bredasdorp
# Processing Record 40 of Set 3 | hobart
# Processing Record 41 of Set 3 | mandera
# Processing Record 42 of Set 3 | san francisco
# Processing Record 43 of Set 3 | teguldet
# Processing Record 44 of Set 3 | korla
# Processing Record 45 of Set 3 | griffith
# Processing Record 46 of Set 3 | kamariotissa
# Processing Record 47 of Set 3 | te anau
# Processing Record 48 of Set 3 | pitea
# Processing Record 49 of Set 3 | ilheus
# Processing Record 50 of Set 3 | wuwei
# Processing Record 1 of Set 4 | sri aman
# Processing Record 2 of Set 4 | zabaykalsk
# Processing Record 3 of Set 4 | new norfolk
# Processing Record 4 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 4 | sassandra
# Processing Record 6 of Set 4 | muborak
# Processing Record 7 of Set 4 | east london
# Processing Record 8 of Set 4 | colares
# Processing Record 9 of Set 4 | innisfail
# Processing Record 10 of Set 4 | pocinhos
# Processing Record 11 of Set 4 | tabuk
# Processing Record 12 of Set 4 | ashland
# Processing Record 13 of Set 4 | nador
# Processing Record 14 of Set 4 | nikolskoye
# Processing Record 15 of Set 4 | chapais
# Processing Record 16 of Set 4 | mahebourg
# Processing Record 17 of Set 4 | bubaque
# Processing Record 18 of Set 4 | gurupa
# Processing Record 19 of Set 4 | codrington
# Processing Record 20 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 4 | mackay
# Processing Record 22 of Set 4 | thompson
# Processing Record 23 of Set 4 | deep river
# Processing Record 24 of Set 4 | coos bay
# Processing Record 25 of Set 4 | sambava
# Processing Record 26 of Set 4 | the valley
# Processing Record 27 of Set 4 | santa maria del oro
# Processing Record 28 of Set 4 | grindavik
# Processing Record 29 of Set 4 | maitum
# Processing Record 30 of Set 4 | fairlie
# Processing Record 31 of Set 4 | manono
# Processing Record 32 of Set 4 | sembe
# Processing Record 33 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 4 | la paz
# Processing Record 35 of Set 4 | aksarka
# Processing Record 36 of Set 4 | camacha
# Processing Record 37 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 4 | longyearbyen
# Processing Record 39 of Set 4 | lavrentiya
# Processing Record 40 of Set 4 | carupano
# Processing Record 41 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 42 of Set 4 | monrovia
# Processing Record 43 of Set 4 | madang
# Processing Record 44 of Set 4 | mpika
# Processing Record 45 of Set 4 | teahupoo
# Processing Record 46 of Set 4 | santarem
# Processing Record 47 of Set 4 | sakakah
# Processing Record 48 of Set 4 | dodola
# Processing Record 49 of Set 4 | chokurdakh
# Processing Record 50 of Set 4 | kaberamaido
# Processing Record 1 of Set 5 | ngerengere
# Processing Record 2 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 5 | airai
# Processing Record 4 of Set 5 | lagoa
# Processing Record 5 of Set 5 | nibe
# Processing Record 6 of Set 5 | maragogi
# Processing Record 7 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 5 | makakilo city
# Processing Record 9 of Set 5 | anchorage
# Processing Record 10 of Set 5 | cidreira
# Processing Record 11 of Set 5 | mattru
# Processing Record 12 of Set 5 | cabo san lucas
# Processing Record 13 of Set 5 | sungairaya
# Processing Record 14 of Set 5 | inverell
# Processing Record 15 of Set 5 | rennes
# Processing Record 16 of Set 5 | viedma
# Processing Record 17 of Set 5 | vila franca do campo
# Processing Record 18 of Set 5 | thurso
# Processing Record 19 of Set 5 | jacareacanga
# Processing Record 20 of Set 5 | karpogory
# Processing Record 21 of Set 5 | turkistan
# Processing Record 22 of Set 5 | vostok
# Processing Record 23 of Set 5 | carutapera
# Processing Record 24 of Set 5 | cayenne
# Processing Record 25 of Set 5 | kintampo
# Processing Record 26 of Set 5 | college
# Processing Record 27 of Set 5 | hasaki
# Processing Record 28 of Set 5 | moerai
# Processing Record 29 of Set 5 | saldanha
# Processing Record 30 of Set 5 | matara
# Processing Record 31 of Set 5 | sitka
# Processing Record 32 of Set 5 | laguna
# Processing Record 33 of Set 5 | norden
# Processing Record 34 of Set 5 | luocheng
# Processing Record 35 of Set 5 | udachnyy
# Processing Record 36 of Set 5 | hami
# Processing Record 37 of Set 5 | aswan
# Processing Record 38 of Set 5 | palauig
# Processing Record 39 of Set 5 | bartica
# Processing Record 40 of Set 5 | senanga
# Processing Record 41 of Set 5 | odessa
# Processing Record 42 of Set 5 | burdur
# Processing Record 43 of Set 5 | axim
# Processing Record 44 of Set 5 | nantucket
# Processing Record 45 of Set 5 | san cristobal
# Processing Record 46 of Set 5 | gat
# Processing Record 47 of Set 5 | nhulunbuy
# Processing Record 48 of Set 5 | alice springs
# Processing Record 49 of Set 5 | santa maria
# Processing Record 50 of Set 5 | karamea
# City not found. Skipping...
# Processing Record 1 of Set 6 | montepuez
# Processing Record 2 of Set 6 | bogovarovo
# Processing Record 3 of Set 6 | lebu
# Processing Record 4 of Set 6 | tromso
# Processing Record 5 of Set 6 | afmadu
# City not found. Skipping...
# Processing Record 6 of Set 6 | atuona
# Processing Record 7 of Set 6 | vao
# Processing Record 8 of Set 6 | ilulissat
# Processing Record 9 of Set 6 | neuquen
# Processing Record 10 of Set 6 | ahrensburg
# Processing Record 11 of Set 6 | sorong
# Processing Record 12 of Set 6 | oranjemund
# Processing Record 13 of Set 6 | cherskiy
# Processing Record 14 of Set 6 | waddan
# Processing Record 15 of Set 6 | jalu
# Processing Record 16 of Set 6 | alihe
# Processing Record 17 of Set 6 | dudinka
# Processing Record 18 of Set 6 | roald
# Processing Record 19 of Set 6 | kozhva
# Processing Record 20 of Set 6 | severo-kurilsk
# Processing Record 21 of Set 6 | las palmas
# Processing Record 22 of Set 6 | inhambane
# Processing Record 23 of Set 6 | vary
# Processing Record 24 of Set 6 | charters towers
# Processing Record 25 of Set 6 | havelock
# Processing Record 26 of Set 6 | irbil
# Processing Record 27 of Set 6 | coquimbo
# Processing Record 28 of Set 6 | meiganga
# Processing Record 29 of Set 6 | mubi
# Processing Record 30 of Set 6 | bilibino
# Processing Record 31 of Set 6 | san pedro
# Processing Record 32 of Set 6 | umm kaddadah
# Processing Record 33 of Set 6 | anadyr
# Processing Record 34 of Set 6 | avera
# Processing Record 35 of Set 6 | sorland
# Processing Record 36 of Set 6 | comodoro rivadavia
# Processing Record 37 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 6 | lumut
# Processing Record 39 of Set 6 | alta floresta
# Processing Record 40 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 6 | tricase
# Processing Record 42 of Set 6 | katsuura
# Processing Record 43 of Set 6 | esperance
# Processing Record 44 of Set 6 | atambua
# Processing Record 45 of Set 6 | virginia beach
# Processing Record 46 of Set 6 | baracoa
# Processing Record 47 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 48 of Set 6 | san patricio
# Processing Record 49 of Set 6 | faanui
# Processing Record 50 of Set 6 | oshakati
# Processing Record 1 of Set 7 | kaniama
# Processing Record 2 of Set 7 | khorixas
# Processing Record 3 of Set 7 | la ronge
# Processing Record 4 of Set 7 | roma
# Processing Record 5 of Set 7 | harper
# Processing Record 6 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 7 of Set 7 | banda aceh
# Processing Record 8 of Set 7 | brae
# Processing Record 9 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 7 | methven
# Processing Record 12 of Set 7 | oyama
# Processing Record 13 of Set 7 | klang
# Processing Record 14 of Set 7 | araouane
# Processing Record 15 of Set 7 | wanning
# Processing Record 16 of Set 7 | usinsk
# Processing Record 17 of Set 7 | aasiaat
# Processing Record 18 of Set 7 | port macquarie
# Processing Record 19 of Set 7 | the pas
# Processing Record 20 of Set 7 | kushmurun
# Processing Record 21 of Set 7 | bosobolo
# Processing Record 22 of Set 7 | wewak
# Processing Record 23 of Set 7 | bathsheba
# Processing Record 24 of Set 7 | hofn
# Processing Record 25 of Set 7 | quirinopolis
# Processing Record 26 of Set 7 | mapiripan
# Processing Record 27 of Set 7 | tsienyane
# City not found. Skipping...
# Processing Record 28 of Set 7 | san fernando
# Processing Record 29 of Set 7 | aabenraa
# Processing Record 30 of Set 7 | tilichiki
# Processing Record 31 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 32 of Set 7 | karratha
# Processing Record 33 of Set 7 | talnakh
# Processing Record 34 of Set 7 | chinavita
# Processing Record 35 of Set 7 | port said
# Processing Record 36 of Set 7 | klaksvik
# Processing Record 37 of Set 7 | mareeba
# Processing Record 38 of Set 7 | el real de santa maria
# Processing Record 39 of Set 7 | rohnert park
# Processing Record 40 of Set 7 | elizabeth city
# Processing Record 41 of Set 7 | fochville
# Processing Record 42 of Set 7 | leshukonskoye
# Processing Record 43 of Set 7 | fevralsk
# City not found. Skipping...
# Processing Record 44 of Set 7 | henties bay
# Processing Record 45 of Set 7 | cariamanga
# Processing Record 46 of Set 7 | vila
# Processing Record 47 of Set 7 | kushiro
# Processing Record 48 of Set 7 | dunedin
# Processing Record 49 of Set 7 | tual
# Processing Record 50 of Set 7 | yerbogachen
# Processing Record 1 of Set 8 | houma
# Processing Record 2 of Set 8 | kodiak
# Processing Record 3 of Set 8 | gualaquiza
# Processing Record 4 of Set 8 | aden
# Processing Record 5 of Set 8 | wenchi
# Processing Record 6 of Set 8 | vung tau
# Processing Record 7 of Set 8 | ayan
# Processing Record 8 of Set 8 | lithgow
# Processing Record 9 of Set 8 | san quintin
# Processing Record 10 of Set 8 | zhezkazgan
# Processing Record 11 of Set 8 | morristown
# Processing Record 12 of Set 8 | general roca
# Processing Record 13 of Set 8 | wajima
# Processing Record 14 of Set 8 | barra velha
# Processing Record 15 of Set 8 | kamenskiy
# Processing Record 16 of Set 8 | diego de almagro
# Processing Record 17 of Set 8 | buala
# Processing Record 18 of Set 8 | springdale
# Processing Record 19 of Set 8 | yulara
# Processing Record 20 of Set 8 | tuggurt
# City not found. Skipping...
# Processing Record 21 of Set 8 | krasnoselkup
# Processing Record 22 of Set 8 | colonia
# Processing Record 23 of Set 8 | elancourt
# Processing Record 24 of Set 8 | guerrero negro
# Processing Record 25 of Set 8 | okitipupa
# Processing Record 26 of Set 8 | necochea
# Processing Record 27 of Set 8 | emerald
# Processing Record 28 of Set 8 | ocampo
# Processing Record 29 of Set 8 | benghazi
# Processing Record 30 of Set 8 | chincha alta
# Processing Record 31 of Set 8 | killam
# Processing Record 32 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 33 of Set 8 | katobu
# Processing Record 34 of Set 8 | nara
# Processing Record 35 of Set 8 | spassk-dalniy
# Processing Record 36 of Set 8 | husavik
# Processing Record 37 of Set 8 | tuatapere
# Processing Record 38 of Set 8 | kavieng
# Processing Record 39 of Set 8 | linxia
# Processing Record 40 of Set 8 | sur
# Processing Record 41 of Set 8 | saint peter
# Processing Record 42 of Set 8 | ostersund
# Processing Record 43 of Set 8 | belyy yar
# Processing Record 44 of Set 8 | okato
# Processing Record 45 of Set 8 | lawrence
# Processing Record 46 of Set 8 | kinna
# Processing Record 47 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 48 of Set 8 | pemangkat
# Processing Record 49 of Set 8 | umm ruwabah
# City not found. Skipping...
# Processing Record 50 of Set 8 | bajram curri
# Processing Record 1 of Set 9 | kondinskoye
# Processing Record 2 of Set 9 | portland
# Processing Record 3 of Set 9 | denpasar
# Processing Record 4 of Set 9 | stepnyak
# Processing Record 5 of Set 9 | san policarpo
# Processing Record 6 of Set 9 | cap-aux-meules
# Processing Record 7 of Set 9 | karlskoga
# Processing Record 8 of Set 9 | caucaia
# Processing Record 9 of Set 9 | pokaran
# Processing Record 10 of Set 9 | porto walter
# Processing Record 11 of Set 9 | petropavlovka
# Processing Record 12 of Set 9 | kurilsk
# Processing Record 13 of Set 9 | sobolevo
# Processing Record 14 of Set 9 | yar-sale
# Processing Record 15 of Set 9 | masallatah
# Processing Record 16 of Set 9 | marsh harbour
# Processing Record 17 of Set 9 | longonjo
# Processing Record 18 of Set 9 | qinhuangdao
# Processing Record 19 of Set 9 | ardakan
# Processing Record 20 of Set 9 | lengshuijiang
# Processing Record 21 of Set 9 | genhe
# Processing Record 22 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 9 | baykit
# Processing Record 24 of Set 9 | vaitape
# Processing Record 25 of Set 9 | nizhnevartovsk
# Processing Record 26 of Set 9 | balkhash
# Processing Record 27 of Set 9 | gimli
# Processing Record 28 of Set 9 | hervey bay
# Processing Record 29 of Set 9 | kjollefjord
# Processing Record 30 of Set 9 | kovdor
# Processing Record 31 of Set 9 | khani
# Processing Record 32 of Set 9 | staryy nadym
# Processing Record 33 of Set 9 | nome
# Processing Record 34 of Set 9 | kruisfontein
# Processing Record 35 of Set 9 | sangmelima
# Processing Record 36 of Set 9 | nzega
# Processing Record 37 of Set 9 | evensk
# Processing Record 38 of Set 9 | astana
# Processing Record 39 of Set 9 | tuy hoa
# Processing Record 40 of Set 9 | filadelfia
# Processing Record 41 of Set 9 | dharchula
# Processing Record 42 of Set 9 | mandalgovi
# Processing Record 43 of Set 9 | vila do maio
# Processing Record 44 of Set 9 | banfora
# Processing Record 45 of Set 9 | kambar
# Processing Record 46 of Set 9 | clinton
# Processing Record 47 of Set 9 | hambantota
# Processing Record 48 of Set 9 | basco
# Processing Record 49 of Set 9 | verkhnyaya inta
# Processing Record 50 of Set 9 | lorengau
# Processing Record 1 of Set 10 | nichinan
# Processing Record 2 of Set 10 | padang
# Processing Record 3 of Set 10 | iqaluit
# Processing Record 4 of Set 10 | santa rosa
# Processing Record 5 of Set 10 | mecca
# Processing Record 6 of Set 10 | hamilton
# Processing Record 7 of Set 10 | kannangad
# Processing Record 8 of Set 10 | kaitangata
# Processing Record 9 of Set 10 | zhigansk
# Processing Record 10 of Set 10 | la romana
# Processing Record 11 of Set 10 | malibu
# Processing Record 12 of Set 10 | coihaique
# Processing Record 13 of Set 10 | orange
# Processing Record 14 of Set 10 | susanville
# Processing Record 15 of Set 10 | kropotkin
# Processing Record 16 of Set 10 | bay roberts
# Processing Record 17 of Set 10 | plastun
# Processing Record 18 of Set 10 | nemuro
# Processing Record 19 of Set 10 | dunmore town
# Processing Record 20 of Set 10 | kavaratti
# Processing Record 21 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 22 of Set 10 | kualakapuas
# Processing Record 23 of Set 10 | kirakira
# Processing Record 24 of Set 10 | umea
# Processing Record 25 of Set 10 | sao jose da coroa grande
# Processing Record 26 of Set 10 | aksay
# Processing Record 27 of Set 10 | batagay-alyta
# Processing Record 28 of Set 10 | jember
# Processing Record 29 of Set 10 | zyryanka
# Processing Record 30 of Set 10 | great yarmouth
# Processing Record 31 of Set 10 | tougue
# Processing Record 32 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 33 of Set 10 | zaykovo
# Processing Record 34 of Set 10 | hun
# Processing Record 35 of Set 10 | torbat-e jam
# Processing Record 36 of Set 10 | requena
# Processing Record 37 of Set 10 | ambilobe
# Processing Record 38 of Set 10 | mabaruma
# Processing Record 39 of Set 10 | hobyo
# Processing Record 40 of Set 10 | oros
# Processing Record 41 of Set 10 | linqiong
# Processing Record 42 of Set 10 | beira
# Processing Record 43 of Set 10 | hays
# Processing Record 44 of Set 10 | mitu
# Processing Record 45 of Set 10 | a
# City not found. Skipping...
# Processing Record 46 of Set 10 | loncoche
# Processing Record 47 of Set 10 | kukes
# Processing Record 48 of Set 10 | flinders
# Processing Record 49 of Set 10 | milkovo
# Processing Record 50 of Set 10 | baldwin
# Processing Record 1 of Set 11 | kabalo
# Processing Record 2 of Set 11 | florenville
# Processing Record 3 of Set 11 | boende
# Processing Record 4 of Set 11 | port hawkesbury
# Processing Record 5 of Set 11 | noyon
# Processing Record 6 of Set 11 | mentok
# City not found. Skipping...
# Processing Record 7 of Set 11 | platikambos
# Processing Record 8 of Set 11 | tartki
# City not found. Skipping...
# Processing Record 9 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 10 of Set 11 | leningradskiy
# Processing Record 11 of Set 11 | auki
# Processing Record 12 of Set 11 | pangody
# Processing Record 13 of Set 11 | waingapu
# Processing Record 14 of Set 11 | angol
# Processing Record 15 of Set 11 | santa fe
# Processing Record 16 of Set 11 | medvezhyegorsk
# Processing Record 17 of Set 11 | nakhon phanom
# Processing Record 18 of Set 11 | outjo
# Processing Record 19 of Set 11 | ingraj bazar
# Processing Record 20 of Set 11 | feijo
# Processing Record 21 of Set 11 | calceta
# Processing Record 22 of Set 11 | idappadi
# Processing Record 23 of Set 11 | custodia
# Processing Record 24 of Set 11 | manavalakurichi
# Processing Record 25 of Set 11 | isabela
# Processing Record 26 of Set 11 | bakchar
# Processing Record 27 of Set 11 | pangnirtung
# Processing Record 28 of Set 11 | nenagh
# Processing Record 29 of Set 11 | cap malheureux
# Processing Record 30 of Set 11 | albert lea
# Processing Record 31 of Set 11 | paramonga
# Processing Record 32 of Set 11 | pacific grove
# Processing Record 33 of Set 11 | novoagansk
# Processing Record 34 of Set 11 | hammerfest
# Processing Record 35 of Set 11 | arman
# Processing Record 36 of Set 11 | coolum beach
# Processing Record 37 of Set 11 | srednekolymsk
# Processing Record 38 of Set 11 | luwuk
# Processing Record 39 of Set 11 | tsiroanomandidy
# Processing Record 40 of Set 11 | ritchie
# Processing Record 41 of Set 11 | marsa matruh
# Processing Record 42 of Set 11 | bonavista
# Processing Record 43 of Set 11 | talah
# City not found. Skipping...
# Processing Record 44 of Set 11 | camocim
# Processing Record 45 of Set 11 | ye
# City not found. Skipping...
# Processing Record 46 of Set 11 | havre-saint-pierre
# Processing Record 47 of Set 11 | novokayakent
# Processing Record 48 of Set 11 | constitucion
# Processing Record 49 of Set 11 | komsomolskiy
# Processing Record 50 of Set 11 | khor
# Processing Record 1 of Set 12 | shingu
# Processing Record 2 of Set 12 | oga
# Processing Record 3 of Set 12 | pontianak
# Processing Record 4 of Set 12 | geraldton
# Processing Record 5 of Set 12 | mehamn
# Processing Record 6 of Set 12 | xai-xai
# Processing Record 7 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 8 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 9 of Set 12 | lucea
# Processing Record 10 of Set 12 | morro bay
# Processing Record 11 of Set 12 | port hedland
# Processing Record 12 of Set 12 | valparaiso
# Processing Record 13 of Set 12 | acapulco
# Processing Record 14 of Set 12 | muros
# Processing Record 15 of Set 12 | surgut
# Processing Record 16 of Set 12 | aksu
# Processing Record 17 of Set 12 | ust-kulom
# Processing Record 18 of Set 12 | ust-nera
# Processing Record 19 of Set 12 | ubinskoye
# Processing Record 20 of Set 12 | salalah
# Processing Record 21 of Set 12 | xuddur
# Processing Record 22 of Set 12 | san felipe
# Processing Record 23 of Set 12 | chernyshevskiy
# Processing Record 24 of Set 12 | chlorakas
# Processing Record 25 of Set 12 | andenes
# Processing Record 26 of Set 12 | senmonorom
# City not found. Skipping...
# Processing Record 27 of Set 12 | craig
# Processing Record 28 of Set 12 | menongue
# Processing Record 29 of Set 12 | krasavino
# Processing Record 30 of Set 12 | fare
# Processing Record 31 of Set 12 | dawei
# Processing Record 32 of Set 12 | meadow lake
# Processing Record 33 of Set 12 | kiama
# Processing Record 34 of Set 12 | abu samrah
# Processing Record 35 of Set 12 | bam
# Processing Record 36 of Set 12 | ahmadpur east
# Processing Record 37 of Set 12 | sibolga
# Processing Record 38 of Set 12 | yandoon
# City not found. Skipping...
# Processing Record 39 of Set 12 | paucartambo
# City not found. Skipping...
# Processing Record 40 of Set 12 | perth
# Processing Record 41 of Set 12 | puerto ayacucho
# Processing Record 42 of Set 12 | uk
# City not found. Skipping...
# Processing Record 43 of Set 12 | willmar
# Processing Record 44 of Set 12 | nacala
# Processing Record 45 of Set 12 | bagalkot
# Processing Record 46 of Set 12 | mayumba
# Processing Record 47 of Set 12 | tomatlan
# Processing Record 48 of Set 12 | mount isa
# Processing Record 49 of Set 12 | tondano
# Processing Record 50 of Set 12 | laje
# Processing Record 1 of Set 13 | doha
# Processing Record 2 of Set 13 | galesong
# Processing Record 3 of Set 13 | barroualie
# City not found. Skipping...
# Processing Record 4 of Set 13 | robertsport
# Processing Record 5 of Set 13 | kaeo
# Processing Record 6 of Set 13 | jega
# Processing Record 7 of Set 13 | amapa
# Processing Record 8 of Set 13 | mehkar
# Processing Record 9 of Set 13 | tabou
# Processing Record 10 of Set 13 | soyo
# Processing Record 11 of Set 13 | rudbar
# Processing Record 12 of Set 13 | copiapo
# Processing Record 13 of Set 13 | zambrow
# Processing Record 14 of Set 13 | ancud
# Processing Record 15 of Set 13 | bend
# Processing Record 16 of Set 13 | tucuman
# Processing Record 17 of Set 13 | kalmunai
# Processing Record 18 of Set 13 | moisakula
# Processing Record 19 of Set 13 | kuhdasht
# Processing Record 20 of Set 13 | pokhara
# Processing Record 21 of Set 13 | thinadhoo
# Processing Record 22 of Set 13 | kudahuvadhoo
# Processing Record 23 of Set 13 | aykhal
# Processing Record 24 of Set 13 | talcahuano
# Processing Record 25 of Set 13 | peru
# Processing Record 26 of Set 13 | sioux lookout
# Processing Record 27 of Set 13 | ponta delgada
# Processing Record 28 of Set 13 | taksimo
# Processing Record 29 of Set 13 | bilma
# Processing Record 30 of Set 13 | whitianga
# Processing Record 31 of Set 13 | ravar
# Processing Record 32 of Set 13 | tafresh
# Processing Record 33 of Set 13 | aljezur
# Processing Record 34 of Set 13 | raudeberg
# Processing Record 35 of Set 13 | port blair
# Processing Record 36 of Set 13 | piacabucu
# Processing Record 37 of Set 13 | goderich
# Processing Record 38 of Set 13 | shimoda
# Processing Record 39 of Set 13 | nelson bay
# Processing Record 40 of Set 13 | ksenyevka
# City not found. Skipping...
# Processing Record 41 of Set 13 | kachikau
# City not found. Skipping...
# Processing Record 42 of Set 13 | santa isabel do rio negro
# Processing Record 43 of Set 13 | villarrobledo
# Processing Record 44 of Set 13 | zharkent
# Processing Record 45 of Set 13 | yumen
# Processing Record 46 of Set 13 | cacapava do sul
# Processing Record 47 of Set 13 | zhaozhou
# Processing Record 48 of Set 13 | red bluff
# Processing Record 49 of Set 13 | poplar bluff
# Processing Record 50 of Set 13 | lodja
# Processing Record 1 of Set 14 | belmonte
# Processing Record 2 of Set 14 | zarechnyy
# Processing Record 3 of Set 14 | maningrida
# Processing Record 4 of Set 14 | cabedelo
# Processing Record 5 of Set 14 | vestmanna
# Processing Record 6 of Set 14 | kahului
# Processing Record 7 of Set 14 | mogoytuy
# Processing Record 8 of Set 14 | beringovskiy
# Processing Record 9 of Set 14 | whitehorse
# Processing Record 10 of Set 14 | port lincoln
# Processing Record 11 of Set 14 | tabora
# Processing Record 12 of Set 14 | sidi bu zayd
# City not found. Skipping...
# Processing Record 13 of Set 14 | sabzevar
# Processing Record 14 of Set 14 | ozgon
# City not found. Skipping...
# Processing Record 15 of Set 14 | senneterre
# Processing Record 16 of Set 14 | sinnamary
# Processing Record 17 of Set 14 | ust-tsilma
# Processing Record 18 of Set 14 | san juan
# Processing Record 19 of Set 14 | ginda
# Processing Record 20 of Set 14 | severnoye
# Processing Record 21 of Set 14 | orchard homes
# Processing Record 22 of Set 14 | malinyi
# Processing Record 23 of Set 14 | balaipungut
# Processing Record 24 of Set 14 | ryotsu
# Processing Record 25 of Set 14 | payo
# Processing Record 26 of Set 14 | lompoc
# Processing Record 27 of Set 14 | prince rupert
# Processing Record 28 of Set 14 | quesnel
# Processing Record 29 of Set 14 | ifo
# Processing Record 30 of Set 14 | saint george
# Processing Record 31 of Set 14 | asfi
# Processing Record 32 of Set 14 | nuevo progreso
# Processing Record 33 of Set 14 | nizwa
# Processing Record 34 of Set 14 | pizhanka
# Processing Record 35 of Set 14 | mergui
# City not found. Skipping...
# Processing Record 36 of Set 14 | cuamba
# Processing Record 37 of Set 14 | kristinehamn
# Processing Record 38 of Set 14 | puerto leguizamo
# Processing Record 39 of Set 14 | kurumkan
# Processing Record 40 of Set 14 | grong
# Processing Record 41 of Set 14 | ugoofaaru
# Processing Record 42 of Set 14 | urumqi
# Processing Record 43 of Set 14 | rio gallegos
# Processing Record 44 of Set 14 | rapar
# Processing Record 45 of Set 14 | port hardy
# Processing Record 46 of Set 14 | chara
# Processing Record 47 of Set 14 | aleksandrovsk-sakhalinskiy
# Processing Record 48 of Set 14 | mudgee
# Processing Record 49 of Set 14 | tagusao
# Processing Record 50 of Set 14 | grimari
# City not found. Skipping...
# Processing Record 1 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 2 of Set 15 | kathmandu
# Processing Record 3 of Set 15 | anderson
# Processing Record 4 of Set 15 | kingaroy
# Processing Record 5 of Set 15 | ngunguru
# Processing Record 6 of Set 15 | maldonado
# Processing Record 7 of Set 15 | olafsvik
# Processing Record 8 of Set 15 | mayor pablo lagerenza
# Processing Record 9 of Set 15 | abu jubayhah
# City not found. Skipping...
# Processing Record 10 of Set 15 | rolim de moura
# City not found. Skipping...
# Processing Record 11 of Set 15 | ballina
# Processing Record 12 of Set 15 | dhidhdhoo
# Processing Record 13 of Set 15 | beloha
# Processing Record 14 of Set 15 | khandbari
# Processing Record 15 of Set 15 | xining
# Processing Record 16 of Set 15 | sabha
# Processing Record 17 of Set 15 | port augusta
# Processing Record 18 of Set 15 | male
# Processing Record 19 of Set 15 | dafeng
# Processing Record 20 of Set 15 | changping
# Processing Record 21 of Set 15 | trofors
# Processing Record 22 of Set 15 | richards bay
# Processing Record 23 of Set 15 | labuhan
# Processing Record 24 of Set 15 | grafton
# Processing Record 25 of Set 15 | sumbawa
# City not found. Skipping...
# Processing Record 26 of Set 15 | touros
# Processing Record 27 of Set 15 | ust-maya
# Processing Record 28 of Set 15 | buchanan
# Processing Record 29 of Set 15 | asilah
# Processing Record 30 of Set 15 | show low
# Processing Record 31 of Set 15 | mount gambier
# Processing Record 32 of Set 15 | alamogordo
# Processing Record 33 of Set 15 | lobanovo
# Processing Record 34 of Set 15 | namwala
# Processing Record 35 of Set 15 | indiana
# Processing Record 36 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 37 of Set 15 | tommot
# Processing Record 38 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 39 of Set 15 | itambacuri
# Processing Record 40 of Set 15 | zhangye
# Processing Record 41 of Set 15 | yerani
# City not found. Skipping...
# Processing Record 42 of Set 15 | bantry
# Processing Record 43 of Set 15 | mata grande
# Processing Record 44 of Set 15 | miri
# Processing Record 45 of Set 15 | eyl
# Processing Record 46 of Set 15 | la palma
# Processing Record 47 of Set 15 | north mankato
# Processing Record 48 of Set 15 | abangay
# Processing Record 49 of Set 15 | taoudenni
# Processing Record 50 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 16 | gorontalo
# Processing Record 2 of Set 16 | neiafu
# Processing Record 3 of Set 16 | kodinar
# Processing Record 4 of Set 16 | jocoro
# Processing Record 5 of Set 16 | turinskaya sloboda
# Processing Record 6 of Set 16 | tautira
# Processing Record 7 of Set 16 | seoul
# Processing Record 8 of Set 16 | port shepstone
# Processing Record 9 of Set 16 | novyy urgal
# Processing Record 10 of Set 16 | hashtrud
# Processing Record 11 of Set 16 | tazovskiy
# Processing Record 12 of Set 16 | shakawe
# Processing Record 13 of Set 16 | macusani
# Processing Record 14 of Set 16 | mrirt
# City not found. Skipping...
# Processing Record 15 of Set 16 | kerman
# Processing Record 16 of Set 16 | surt
# Processing Record 17 of Set 16 | burgeo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 707

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                    City Country      Lat       Lng  Max Temp  Humidity  \
# 0                 Vaini      TO -21.2000 -175.2000     84.20        84
# 1            Butaritari      KI   3.0707  172.7902     81.23        79
# 2                Klaeng      TH  12.7797  101.6483     75.99        89
# 3                Narsaq      GL  60.9167  -46.0500     23.16        81
# 4               Aklavik      CA  68.2191 -135.0107     -7.60        71
# 5                   Ada      US  43.4166 -116.1262     51.80        34
# 6             Crestline      US  34.2420 -117.2856     73.40        17
# 7                  Bogo      PH  11.0517  124.0055     81.73        77
# 8  Nikolayevsk-Na-Amure      RU  53.1406  140.7300     -3.30        88
# 9                  Chuy      UY -33.6971  -53.4616     67.05        88
#
#    Cloudiness  Wind Speed Current Description
# 0          75        9.22       broken clouds
# 1          71       20.20       broken clouds
# 2           2        2.35           clear sky
# 3         100        3.65     overcast clouds
# 4          90       11.50     overcast clouds
# 5          90        8.05     overcast clouds
# 6           1        6.91           clear sky
# 7          99       12.55     overcast clouds
# 8         100        6.38     overcast clouds
# 9           0        9.71           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file)
